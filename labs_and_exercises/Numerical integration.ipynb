# %%
import math
import matplotlib.pylab as plt

xpts = []
ypts = []
for i in range(0,100):
    x = i*0.1
    y = math.sin(x)
    xpts.append(x)
    ypts.append(y)
    
plt.plot(xpts,ypts,'b-')
plt.show()
